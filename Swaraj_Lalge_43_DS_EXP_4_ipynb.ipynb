# %% [markdown]
# <a href="https://colab.research.google.com/github/SRLALGE/PLANT/blob/main/Swaraj_Lalge_43_DS_EXP_4_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/drive/MyDrive/abalone.csv')
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB
# None

# %%
df_encoded = pd.get_dummies(df, columns=['Height'])
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df.iloc[:, 1:])  # Exclude the first column
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-29b405ddcdcb> in <cell line: 4>()
#       2
#       3 scaler = StandardScaler()
# ----> 4 df_scaled = scaler.fit_transform(df.iloc[:, 1:])  # Exclude the first column
#       5 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Read your CSV (replace with actual file path)
df = pd.read_csv('/content/drive/MyDrive/abalone.csv')

# One-Hot Encode the categorical column
df_encoded = pd.get_dummies(df, columns=['Shell weight'])

# Separate features and target (assuming a target variable exists)
X = df_encoded.iloc[:, 1:]  # Exclude the first column (index)
y = df_encoded.iloc[:, 0]  # Assuming the target is in the first column

# Standardize numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Now you have a preprocessed dataset with normalized/scaled numerical features and encoded categorical features.
X
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Rings  Shell weight_0.0015  Shell weight_0.003  Shell weight_0.0035  \
# 0        15                False               False                False
# 1         7                False               False                False
# 2         9                False               False                False
# 3        10                False               False                False
# 4         7                False               False                False
# ...     ...                  ...                 ...                  ...
# 4172     11                False               False                False
# 4173     10                False               False                False
# 4174      9                False               False                False
# 4175     10                False               False                False
# 4176     12                False               False                False
#
#       ...  Shell weight_0.725  Shell weight_0.726  Shell weight_0.76  \
# 0     ...               False               False              False
# 1     ...               False               False              False
# 2     ...               False               False              False
# 3     ...               False               False              False
# 4     ...               False               False              False
# ...   ...                 ...                 ...                ...
# 4172  ...               False               False              False
# 4173  ...               False               False              False
# 4174  ...               False               False              False
# 4175  ...               False               False              False
# 4176  ...               False               False              False
#
#       Shell weight_0.78  Shell weight_0.7975  Shell weight_0.815  \
# 0                 False                False               False
# 1                 False                False               False
# 2                 False                False               False
# 3                 False                False               False
# 4                 False                False               False
# ...                 ...                  ...                 ...
# 4172              False                False               False
# 4173              False                False               False
# 4174              False                False               False
# 4175              False                False               False
# 4176              False                False               False
#
#       Shell weight_0.85  Shell weight_0.885  Shell weight_0.897  \
# 0                 False               False               False
# 1                 False               False               False
# 2                 False               False               False
# 3                 False               False               False
# 4                 False               False               False
# ...                 ...                 ...                 ...
# 4172              False               False               False
# 4173              False               False               False
# 4174              False               False               False
# 4175              False               False               False
# 4176              False               False               False
#
#       Shell weight_1.005
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ...                  ...
# 4172               False
# 4173               False
# 4174               False
# 4175               False
# 4176               False
#
# [4177 rows x 933 columns]

# %%
X_scaled
# Out:
# array([[-0.57455813, -0.43214879, -1.06442415, ..., -0.02188703,
#         -0.01547461, -0.01547461],
#        [-1.44898585, -1.439929  , -1.18397831, ..., -0.02188703,
#         -0.01547461, -0.01547461],
#        [ 0.05003309,  0.12213032, -0.10799087, ..., -0.02188703,
#         -0.01547461, -0.01547461],
#        ...,
#        [ 0.6329849 ,  0.67640943,  1.56576738, ..., -0.02188703,
#         -0.01547461, -0.01547461],
#        [ 0.84118198,  0.77718745,  0.25067161, ..., -0.02188703,
#         -0.01547461, -0.01547461],
#        [ 1.54905203,  1.48263359,  1.32665906, ..., -0.02188703,
#         -0.01547461, -0.01547461]])
